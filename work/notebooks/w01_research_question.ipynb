# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Om-Ranmode/flyrank-ml-internshipPractice/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# ## My Lane
#
# I selected **Refresh / Content Opportunity Scoring** as my provisional lane. The goal of this project is to identify which content pages should be reviewed first by analyzing observable search and engagement metrics. Instead of manually checking every page, this approach helps prioritize pages that may benefit the most from updates. I chose this lane because the starter dataset contains content performance, freshness, and engagement information that is suitable for building an evidence-based ranking system.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("flyrank-ml-internshipPractice/data/raw/content_refresh_anonymized.csv")

print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## Research Question
#
# **Research Question**
#
# Can search performance and engagement metrics be used to identify which content pages should be reviewed first for improvement?
#
# **Decision**
#
# The project supports the decision of selecting high-priority pages for content review.
#
# **Who takes the action?**
#
# SEO specialists and content teams use the ranked list to decide which pages should be updated, expanded, or monitored.
#
# **Cost of a wrong recommendation**
#
# If an important page is missed, potential improvements in search visibility and user engagement may be lost. If a low-priority page is selected, time and resources are spent on content with limited improvement potential.
#
# Machine learning is appropriate because it can evaluate many performance indicators together and identify useful patterns that are difficult to detect manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (30000, 44)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# ## Quick Look at the Data
#
# The starter dataset contains **_____** content records and **_____** features.
#
# The average number of impressions during the last 90 days is **_____**.
#
# The `trend_direction` column contains multiple categories such as **up**, **down**, **stable**, and **new**, providing useful information for identifying content that may require review.
#
# These observations suggest that the dataset provides sufficient search and engagement information to investigate content refresh opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nTrend Direction Distribution")
print(df["trend_direction"].value_counts())

print("\nAverage Impressions (90d):")
print(round(df["impressions_90d"].mean(),2))

print("\nAverage CTR:")
print(round(df["ctr"].mean(),2))
# Out:
# Rows: 30000
# Columns: 44
#
# Trend Direction Distribution
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average Impressions (90d):
# 5200.37
#
# Average CTR:
# 0.51

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# ## Careful Words
#
# This project is intended to support content review decisions by identifying patterns in historical search and engagement data.
#
# The results can highlight pages that may deserve further attention, but they do not prove that updating a page will directly improve rankings or traffic. The findings are based on observed data and should be used as decision-support rather than as guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Notebook completed successfully.")
# Out:
# Notebook completed successfully.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
